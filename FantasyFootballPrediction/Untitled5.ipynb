# %%
# Copyright (c) Roman Lutz. All rights reserved.
# The use and distribution terms for this software are covered by the
# Eclipse Public License 1.0 (http://opensource.org/licenses/eclipse-1.0.php)
# which can be found in the file LICENSE.md at the root of this distribution.
# By using this software in any fashion, you are agreeing to be bound by
# the terms of this license.
# You must not remove this notice, or any other, from this software.

import pdb
import numpy as np
from sklearn.svm import SVR
from sklearn import preprocessing
from sklearn import cross_validation
from sklearn import feature_selection
from sklearn.metrics import mean_squared_error, mean_absolute_error
from create_datasets import test_players
import time
from metrics import mean_relative_error
from plots import histogram
import sklearn.model_selection
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import GridSearchCV
import sklearn









kernels = ['rbf', 'linear', 'sigmoid']
degrees = [2, 3]
gamma_values = [0.05*k for k in range(1,4)]
C_values = [0.25*k for k in range(1, 5)]
epsilon_values = [0.05*k for k in range(1, 6)]
score = 'neg_median_absolute_error'




def hyperparameter(x, y):

    # elements of this list are dictionaries that contain the best parameters for each kernel to use on test data (2017 data)
    overall_best_params = []

    # linear
    linear_kernel = ['linear']
    linear_parameters = {'kernel':(linear_kernel), 'C':(C_values), 'gamma':(gamma_values), 'epsilon':(epsilon_values)}
    # Since we are predicting scores and using regression, use SVR()
    svr = sklearn.svm.SVR()
    clf = sklearn.model_selection.GridSearchCV(svr, linear_parameters, verbose=5, scoring=score)
    clf.fit(x, y)
    cvres = clf.cv_results_
    linear_kernel_data = open('linear_kernel_data.txt', 'w')
    print("LINEAR:")
    for mean_score, params in zip(cvres["mean_test_score"], cvres["params"]):
        print(mean_score, params)
        linear_kernel_data.write(str(mean_score) + " " + str(params))
    print("Best: " + str(clf.best_params_))
    overall_best_params.append(clf.best_params_)
    linear_kernel_data.close()

    # rbf
    rbf_kernel = ['rbf']
    rbf_parameters = {'kernel':(rbf_kernel), 'C':(C_values), 'gamma':(gamma_values), 'epsilon':(epsilon_values)}
    svr = sklearn.svm.SVR()
    clf = sklearn.model_selection.GridSearchCV(svr, rbf_parameters, verbose=5, scoring=score)
    clf.fit(x, y)
    cvres = clf.cv_results_
    rbf_kernel_data = open('rbf_kernel_data.txt', 'w')
    print("RBF:")
    for mean_score, params in zip(cvres["mean_test_score"], cvres["params"]):
        print(mean_score, params)
        rbf_kernel_data.write(str(mean_score) + " " + str(params))
    print("Best: " + str(clf.best_params_))
    overall_best_params.append(clf.best_params_)
    rbf_kernel_data.close()

    # sigmoid
    sigmoid_kernel = ['sigmoid']
    sigmoid_parameters = {'kernel':(sigmoid_kernel), 'C':(C_values), 'gamma':(gamma_values), 'epsilon':(epsilon_values)}
    svr = sklearn.svm.SVR()
    clf = sklearn.model_selection.GridSearchCV(svr, sigmoid_parameters, verbose=5, scoring=score)
    clf.fit(x, y)
    cvres = clf.cv_results_
    sigmoid_kernel_data = open('sigmoid_kernel_data.txt', 'w')
    print("SIGMOID:")
    for mean_score, params in zip(cvres["mean_test_score"], cvres["params"]):
        print(mean_score, params)
        sigmoid_kernel_data.write(str(mean_score) + " " + str(params))
    print("Best: " + str(clf.best_params_))
    overall_best_params.append(clf.best_params_)
    sigmoid_kernel_data.close()

    # overall best parameters to use on test data (2017 season)
    print("RUN BEST PARAMETERS ON TEST DATA (2017):")
    svr = sklearn.svm.SVR()
    clf = sklearn.model_selection.GridSearchCV(svr, (param for param in overall_best_params), verbose=5, scoring=score)
    clf.fit(test_x, test_y)
    cvres = clf.cv_results_
    best_kernel_data = open('best_kernel_data.txt', 'w')
    for mean_score, params in zip(cvres["mean_test_score"], cvres["params"]):
        print(mean_score, params)
        best_kernel_data.write(str(mean_score) + " " + str(params))
    print("Best: " + str(clf.best_params_))
    best_kernel_data.close()
    print("FEATURE SELECTION FINISHED")







# Only one of the feature selection methods can be chosen
FEATURE_SELECTION = False
MANUAL_FEATURE_SELECTION = False
FEATURE_NORMALIZATION = False
HYPERPARAMETER_SELECTION = True
HISTOGRAM = True


"""
train = np.load('train.npy')
test = np.load('test.npy')

train_x = train[:, 2:36].astype(np.float)
train_y = train[:, 36].astype(np.float)
test_x = test[:, 2:36].astype(np.float)
test_y = test[:, 36].astype(np.float)
pdb.set_trace()
"""
"""
# load data
# indices are
# 0: QB id
# 1: QB name
# 2: QB age
# 3: QB years pro
# 4
# 5-16: last game QB stats
# 17-28: last 10 games QB stats
# 29-32: last game defense stats
# 33-36: last 10 games defense stats
# 37: actual fantasy score = target
"""

train = np.load('train.npy')
test = np.load('test.npy')

train_x = train[:, 2:37].astype(np.float)
train_y = train[:, 37].astype(np.float)
test_x = test[:, 2:37].astype(np.float)
test_y = test[:, 37].astype(np.float)



#kernels = ['rbf', 'linear', 'sigmoid', 'poly']
kernels = ['rbf', 'linear', 'sigmoid']
degrees = [2, 3]
gamma_values = [0.05*k for k in range(1,4)]
C_values = [0.25*k for k in range(1, 5)]
epsilon_values = [0.05*k for k in range(1, 6)]

# Feature Normalization
if FEATURE_NORMALIZATION:
    print 'started feature normalization', time.time()
    x = np.concatenate((train_x, test_x), axis=0)
    x = preprocessing.scale(x)
    train_x = x[:len(train_x)]
    test_x = x[len(train_x):]


# Recursive Feature Elimination with cross-validation (RFECV)
if FEATURE_SELECTION:
    print 'started feature selection', time.time()
    selector = feature_selection.RFECV(estimator=SVR(kernel='linear'), step=3, cv=5)
    selector.fit(train_x, train_y)
    train_x = selector.transform(train_x)
    test_x = selector.transform(test_x)
    print selector.ranking_
elif MANUAL_FEATURE_SELECTION: # leave out the two point attempts
    manual_indices = [0, 1, 2, 3, 4, 5, 8, 9, 10, 13, 14, 15, 16, 17, 20, 21, 22, 25, 26, 27, 28, 29, 30, 31, 32, 33]
    train_x = train_x[:, manual_indices]
    test_x = test_x[:, manual_indices]

# USE NORMAL KFOLD
# hyperparameter selection
if HYPERPARAMETER_SELECTION:
    hyperparameter(train_x, train_y)
# Out:
# Fitting 3 folds for each of 60 candidates, totalling 180 fits
# [CV] epsilon=0.05, C=0.25, gamma=0.05, kernel=linear .................
# [CV]  epsilon=0.05, C=0.25, gamma=0.05, kernel=linear, score=-5.03117701925, total=  31.8s
# [CV] epsilon=0.05, C=0.25, gamma=0.05, kernel=linear .................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:   32.1s remaining:    0.0s
# [CV]  epsilon=0.05, C=0.25, gamma=0.05, kernel=linear, score=-5.03126011842, total=  22.6s
# [CV] epsilon=0.05, C=0.25, gamma=0.05, kernel=linear .................
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:   54.9s remaining:    0.0s
# [CV]  epsilon=0.05, C=0.25, gamma=0.05, kernel=linear, score=-5.13903177173, total=  29.6s
# [CV] epsilon=0.05, C=0.25, gamma=0.1, kernel=linear ..................
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:  1.4min remaining:    0.0s
# [CV]  epsilon=0.05, C=0.25, gamma=0.1, kernel=linear, score=-5.03117701925, total=  31.8s
# [CV] epsilon=0.05, C=0.25, gamma=0.1, kernel=linear ..................
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:  1.9min remaining:    0.0s
# [CV]  epsilon=0.05, C=0.25, gamma=0.1, kernel=linear, score=-5.03126011842, total=  22.8s
# [CV] epsilon=0.05, C=0.25, gamma=0.1, kernel=linear ..................
# [CV]  epsilon=0.05, C=0.25, gamma=0.1, kernel=linear, score=-5.13903177173, total=  31.4s
# [CV] epsilon=0.05, C=0.25, gamma=0.15, kernel=linear .................
# [CV]  epsilon=0.05, C=0.25, gamma=0.15, kernel=linear, score=-5.03117701925, total=  33.5s
# [CV] epsilon=0.05, C=0.25, gamma=0.15, kernel=linear .................
# [CV]  epsilon=0.05, C=0.25, gamma=0.15, kernel=linear, score=-5.03126011842, total=  22.8s
# [CV] epsilon=0.05, C=0.25, gamma=0.15, kernel=linear .................
# [CV]  epsilon=0.05, C=0.25, gamma=0.15, kernel=linear, score=-5.13903177173, total=  29.7s
# [CV] epsilon=0.1, C=0.25, gamma=0.05, kernel=linear ..................
# [CV]  epsilon=0.1, C=0.25, gamma=0.05, kernel=linear, score=-5.05860067839, total=  24.2s
# [CV] epsilon=0.1, C=0.25, gamma=0.05, kernel=linear ..................
# [CV]  epsilon=0.1, C=0.25, gamma=0.05, kernel=linear, score=-5.04439764403, total=  25.4s
# [CV] epsilon=0.1, C=0.25, gamma=0.05, kernel=linear ..................
# [CV]  epsilon=0.1, C=0.25, gamma=0.05, kernel=linear, score=-5.1841640537, total=  24.6s
# [CV] epsilon=0.1, C=0.25, gamma=0.1, kernel=linear ...................
# [CV]  epsilon=0.1, C=0.25, gamma=0.1, kernel=linear, score=-5.05860067839, total=  23.9s
# [CV] epsilon=0.1, C=0.25, gamma=0.1, kernel=linear ...................
# [CV]  epsilon=0.1, C=0.25, gamma=0.1, kernel=linear, score=-5.04439764403, total=  25.4s
# [CV] epsilon=0.1, C=0.25, gamma=0.1, kernel=linear ...................
# [CV]  epsilon=0.1, C=0.25, gamma=0.1, kernel=linear, score=-5.1841640537, total=  25.3s
# [CV] epsilon=0.1, C=0.25, gamma=0.15, kernel=linear ..................
# [CV]  epsilon=0.1, C=0.25, gamma=0.15, kernel=linear, score=-5.05860067839, total=  24.0s
# [CV] epsilon=0.1, C=0.25, gamma=0.15, kernel=linear ..................
# [CV]  epsilon=0.1, C=0.25, gamma=0.15, kernel=linear, score=-5.04439764403, total=  26.0s
# [CV] epsilon=0.1, C=0.25, gamma=0.15, kernel=linear ..................
# [CV]  epsilon=0.1, C=0.25, gamma=0.15, kernel=linear, score=-5.1841640537, total=  24.8s
# [CV] epsilon=0.15, C=0.25, gamma=0.05, kernel=linear .................
# [CV]  epsilon=0.15, C=0.25, gamma=0.05, kernel=linear, score=-5.01293550297, total=  21.6s
# [CV] epsilon=0.15, C=0.25, gamma=0.05, kernel=linear .................
# [CV]  epsilon=0.15, C=0.25, gamma=0.05, kernel=linear, score=-5.02783692558, total=  24.5s
# [CV] epsilon=0.15, C=0.25, gamma=0.05, kernel=linear .................
# [CV]  epsilon=0.15, C=0.25, gamma=0.05, kernel=linear, score=-5.18403958718, total=  25.4s
# [CV] epsilon=0.15, C=0.25, gamma=0.1, kernel=linear ..................
# [CV]  epsilon=0.15, C=0.25, gamma=0.1, kernel=linear, score=-5.01293550297, total=  21.6s
# [CV] epsilon=0.15, C=0.25, gamma=0.1, kernel=linear ..................
# [CV]  epsilon=0.15, C=0.25, gamma=0.1, kernel=linear, score=-5.02783692558, total=  24.5s
# [CV] epsilon=0.15, C=0.25, gamma=0.1, kernel=linear ..................
# [CV]  epsilon=0.15, C=0.25, gamma=0.1, kernel=linear, score=-5.18403958718, total=  25.5s
# [CV] epsilon=0.15, C=0.25, gamma=0.15, kernel=linear .................
# [CV]  epsilon=0.15, C=0.25, gamma=0.15, kernel=linear, score=-5.01293550297, total=  21.6s
# [CV] epsilon=0.15, C=0.25, gamma=0.15, kernel=linear .................
# [CV]  epsilon=0.15, C=0.25, gamma=0.15, kernel=linear, score=-5.02783692558, total=  24.5s
# [CV] epsilon=0.15, C=0.25, gamma=0.15, kernel=linear .................
# [CV]  epsilon=0.15, C=0.25, gamma=0.15, kernel=linear, score=-5.18403958718, total=  25.4s
# [CV] epsilon=0.2, C=0.25, gamma=0.05, kernel=linear ..................
# [CV]  epsilon=0.2, C=0.25, gamma=0.05, kernel=linear, score=-5.01854873446, total=  24.0s
# [CV] epsilon=0.2, C=0.25, gamma=0.05, kernel=linear ..................
# [CV]  epsilon=0.2, C=0.25, gamma=0.05, kernel=linear, score=-5.04741862926, total=  22.9s
# [CV] epsilon=0.2, C=0.25, gamma=0.05, kernel=linear ..................
# [CV]  epsilon=0.2, C=0.25, gamma=0.05, kernel=linear, score=-5.17687766308, total=  26.2s
# [CV] epsilon=0.2, C=0.25, gamma=0.1, kernel=linear ...................
# [CV]  epsilon=0.2, C=0.25, gamma=0.1, kernel=linear, score=-5.01854873446, total=  24.0s
# [CV] epsilon=0.2, C=0.25, gamma=0.1, kernel=linear ...................
# [CV]  epsilon=0.2, C=0.25, gamma=0.1, kernel=linear, score=-5.04741862926, total=  23.0s
# [CV] epsilon=0.2, C=0.25, gamma=0.1, kernel=linear ...................
# [CV]  epsilon=0.2, C=0.25, gamma=0.1, kernel=linear, score=-5.17687766308, total=  26.1s
# [CV] epsilon=0.2, C=0.25, gamma=0.15, kernel=linear ..................
# [CV]  epsilon=0.2, C=0.25, gamma=0.15, kernel=linear, score=-5.01854873446, total=  24.0s
# [CV] epsilon=0.2, C=0.25, gamma=0.15, kernel=linear ..................
# [CV]  epsilon=0.2, C=0.25, gamma=0.15, kernel=linear, score=-5.04741862926, total=  23.0s
# [CV] epsilon=0.2, C=0.25, gamma=0.15, kernel=linear ..................
# [CV]  epsilon=0.2, C=0.25, gamma=0.15, kernel=linear, score=-5.17687766308, total=  26.1s
# [CV] epsilon=0.25, C=0.25, gamma=0.05, kernel=linear .................
# [CV]  epsilon=0.25, C=0.25, gamma=0.05, kernel=linear, score=-5.04160136339, total=  27.0s
# [CV] epsilon=0.25, C=0.25, gamma=0.05, kernel=linear .................
# [CV]  epsilon=0.25, C=0.25, gamma=0.05, kernel=linear, score=-5.0283781826, total=  29.5s
# [CV] epsilon=0.25, C=0.25, gamma=0.05, kernel=linear .................
# [CV]  epsilon=0.25, C=0.25, gamma=0.05, kernel=linear, score=-5.19192290821, total=  33.4s
# [CV] epsilon=0.25, C=0.25, gamma=0.1, kernel=linear ..................
# [CV]  epsilon=0.25, C=0.25, gamma=0.1, kernel=linear, score=-5.04160136339, total=  27.0s
# [CV] epsilon=0.25, C=0.25, gamma=0.1, kernel=linear ..................
# [CV]  epsilon=0.25, C=0.25, gamma=0.1, kernel=linear, score=-5.0283781826, total=  29.6s
# [CV] epsilon=0.25, C=0.25, gamma=0.1, kernel=linear ..................
# [CV]  epsilon=0.25, C=0.25, gamma=0.1, kernel=linear, score=-5.19192290821, total=  33.5s
# [CV] epsilon=0.25, C=0.25, gamma=0.15, kernel=linear .................
# [CV]  epsilon=0.25, C=0.25, gamma=0.15, kernel=linear, score=-5.04160136339, total=  27.0s
# [CV] epsilon=0.25, C=0.25, gamma=0.15, kernel=linear .................
# [CV]  epsilon=0.25, C=0.25, gamma=0.15, kernel=linear, score=-5.0283781826, total=  29.6s
# [CV] epsilon=0.25, C=0.25, gamma=0.15, kernel=linear .................
# [CV]  epsilon=0.25, C=0.25, gamma=0.15, kernel=linear, score=-5.19192290821, total=  33.4s
# [CV] epsilon=0.05, C=0.5, gamma=0.05, kernel=linear ..................
# [CV]  epsilon=0.05, C=0.5, gamma=0.05, kernel=linear, score=-5.04412004268, total=  54.9s
# [CV] epsilon=0.05, C=0.5, gamma=0.05, kernel=linear ..................
# [CV]  epsilon=0.05, C=0.5, gamma=0.05, kernel=linear, score=-5.03959477474, total=  49.3s
# [CV] epsilon=0.05, C=0.5, gamma=0.05, kernel=linear ..................
# [CV]  epsilon=0.05, C=0.5, gamma=0.05, kernel=linear, score=-5.18654512859, total=  57.3s
# [CV] epsilon=0.05, C=0.5, gamma=0.1, kernel=linear ...................
# [CV]  epsilon=0.05, C=0.5, gamma=0.1, kernel=linear, score=-5.04412004268, total=  54.9s
# [CV] epsilon=0.05, C=0.5, gamma=0.1, kernel=linear ...................
# [CV]  epsilon=0.05, C=0.5, gamma=0.1, kernel=linear, score=-5.03959477474, total=  49.3s
# [CV] epsilon=0.05, C=0.5, gamma=0.1, kernel=linear ...................
# [CV]  epsilon=0.05, C=0.5, gamma=0.1, kernel=linear, score=-5.18654512859, total=  57.2s
# [CV] epsilon=0.05, C=0.5, gamma=0.15, kernel=linear ..................
# [CV]  epsilon=0.05, C=0.5, gamma=0.15, kernel=linear, score=-5.04412004268, total=  55.0s
# [CV] epsilon=0.05, C=0.5, gamma=0.15, kernel=linear ..................
# [CV]  epsilon=0.05, C=0.5, gamma=0.15, kernel=linear, score=-5.03959477474, total=  49.3s
# [CV] epsilon=0.05, C=0.5, gamma=0.15, kernel=linear ..................
# [CV]  epsilon=0.05, C=0.5, gamma=0.15, kernel=linear, score=-5.18654512859, total=  57.3s
# [CV] epsilon=0.1, C=0.5, gamma=0.05, kernel=linear ...................
# [CV]  epsilon=0.1, C=0.5, gamma=0.05, kernel=linear, score=-5.05842425238, total=  54.0s
# [CV] epsilon=0.1, C=0.5, gamma=0.05, kernel=linear ...................
# [CV]  epsilon=0.1, C=0.5, gamma=0.05, kernel=linear, score=-5.03864957686, total=  46.6s
# [CV] epsilon=0.1, C=0.5, gamma=0.05, kernel=linear ...................
# [CV]  epsilon=0.1, C=0.5, gamma=0.05, kernel=linear, score=-5.24036141331, total=  57.2s
# [CV] epsilon=0.1, C=0.5, gamma=0.1, kernel=linear ....................
# [CV]  epsilon=0.1, C=0.5, gamma=0.1, kernel=linear, score=-5.05842425238, total=  54.0s
# [CV] epsilon=0.1, C=0.5, gamma=0.1, kernel=linear ....................
# [CV]  epsilon=0.1, C=0.5, gamma=0.1, kernel=linear, score=-5.03864957686, total=  46.5s
# [CV] epsilon=0.1, C=0.5, gamma=0.1, kernel=linear ....................
# [CV]  epsilon=0.1, C=0.5, gamma=0.1, kernel=linear, score=-5.24036141331, total=  57.2s
# [CV] epsilon=0.1, C=0.5, gamma=0.15, kernel=linear ...................
# [CV]  epsilon=0.1, C=0.5, gamma=0.15, kernel=linear, score=-5.05842425238, total=  54.0s
# [CV] epsilon=0.1, C=0.5, gamma=0.15, kernel=linear ...................
# [CV]  epsilon=0.1, C=0.5, gamma=0.15, kernel=linear, score=-5.03864957686, total=  46.5s
# [CV] epsilon=0.1, C=0.5, gamma=0.15, kernel=linear ...................
# [CV]  epsilon=0.1, C=0.5, gamma=0.15, kernel=linear, score=-5.24036141331, total=  57.1s
# [CV] epsilon=0.15, C=0.5, gamma=0.05, kernel=linear ..................
# [CV]  epsilon=0.15, C=0.5, gamma=0.05, kernel=linear, score=-5.07860729894, total=  56.2s
# [CV] epsilon=0.15, C=0.5, gamma=0.05, kernel=linear ..................
# [CV]  epsilon=0.15, C=0.5, gamma=0.05, kernel=linear, score=-5.03472407963, total=  52.1s
# [CV] epsilon=0.15, C=0.5, gamma=0.05, kernel=linear ..................
# [CV]  epsilon=0.15, C=0.5, gamma=0.05, kernel=linear, score=-5.25463094635, total=  47.2s
# [CV] epsilon=0.15, C=0.5, gamma=0.1, kernel=linear ...................
# [CV]  epsilon=0.15, C=0.5, gamma=0.1, kernel=linear, score=-5.07860729894, total=  56.1s
# [CV] epsilon=0.15, C=0.5, gamma=0.1, kernel=linear ...................
# [CV]  epsilon=0.15, C=0.5, gamma=0.1, kernel=linear, score=-5.03472407963, total=  52.1s
# [CV] epsilon=0.15, C=0.5, gamma=0.1, kernel=linear ...................
# [CV]  epsilon=0.15, C=0.5, gamma=0.1, kernel=linear, score=-5.25463094635, total=  47.1s
# [CV] epsilon=0.15, C=0.5, gamma=0.15, kernel=linear ..................
# [CV]  epsilon=0.15, C=0.5, gamma=0.15, kernel=linear, score=-5.07860729894, total=  56.2s
# [CV] epsilon=0.15, C=0.5, gamma=0.15, kernel=linear ..................
# [CV]  epsilon=0.15, C=0.5, gamma=0.15, kernel=linear, score=-5.03472407963, total=  52.1s
# [CV] epsilon=0.15, C=0.5, gamma=0.15, kernel=linear ..................
# [CV]  epsilon=0.15, C=0.5, gamma=0.15, kernel=linear, score=-5.25463094635, total=  46.9s
# [CV] epsilon=0.2, C=0.5, gamma=0.05, kernel=linear ...................
# [CV]  epsilon=0.2, C=0.5, gamma=0.05, kernel=linear, score=-5.0684929839, total=  47.8s
# [CV] epsilon=0.2, C=0.5, gamma=0.05, kernel=linear ...................
# [CV]  epsilon=0.2, C=0.5, gamma=0.05, kernel=linear, score=-5.03636186257, total= 1.0min
# [CV] epsilon=0.2, C=0.5, gamma=0.05, kernel=linear ...................
# [CV]  epsilon=0.2, C=0.5, gamma=0.05, kernel=linear, score=-5.2031883736, total=  53.1s
# [CV] epsilon=0.2, C=0.5, gamma=0.1, kernel=linear ....................
# [CV]  epsilon=0.2, C=0.5, gamma=0.1, kernel=linear, score=-5.0684929839, total=  47.7s
# [CV] epsilon=0.2, C=0.5, gamma=0.1, kernel=linear ....................
# [CV]  epsilon=0.2, C=0.5, gamma=0.1, kernel=linear, score=-5.03636186257, total= 1.0min
# [CV] epsilon=0.2, C=0.5, gamma=0.1, kernel=linear ....................
# [CV]  epsilon=0.2, C=0.5, gamma=0.1, kernel=linear, score=-5.2031883736, total=  53.2s
# [CV] epsilon=0.2, C=0.5, gamma=0.15, kernel=linear ...................
# [CV]  epsilon=0.2, C=0.5, gamma=0.15, kernel=linear, score=-5.0684929839, total=  47.9s
# [CV] epsilon=0.2, C=0.5, gamma=0.15, kernel=linear ...................
# [CV]  epsilon=0.2, C=0.5, gamma=0.15, kernel=linear, score=-5.03636186257, total= 1.0min
# [CV] epsilon=0.2, C=0.5, gamma=0.15, kernel=linear ...................
# [CV]  epsilon=0.2, C=0.5, gamma=0.15, kernel=linear, score=-5.2031883736, total=  53.0s
# [CV] epsilon=0.25, C=0.5, gamma=0.05, kernel=linear ..................
# [CV]  epsilon=0.25, C=0.5, gamma=0.05, kernel=linear, score=-5.05254373054, total= 1.1min
# [CV] epsilon=0.25, C=0.5, gamma=0.05, kernel=linear ..................
# [CV]  epsilon=0.25, C=0.5, gamma=0.05, kernel=linear, score=-5.02118960808, total=  53.0s
# [CV] epsilon=0.25, C=0.5, gamma=0.05, kernel=linear ..................
# [CV]  epsilon=0.25, C=0.5, gamma=0.05, kernel=linear, score=-5.19108057738, total=  47.2s
# [CV] epsilon=0.25, C=0.5, gamma=0.1, kernel=linear ...................
# [CV]  epsilon=0.25, C=0.5, gamma=0.1, kernel=linear, score=-5.05254373054, total= 1.1min
# [CV] epsilon=0.25, C=0.5, gamma=0.1, kernel=linear ...................
# [CV]  epsilon=0.25, C=0.5, gamma=0.1, kernel=linear, score=-5.02118960808, total=  53.2s
# [CV] epsilon=0.25, C=0.5, gamma=0.1, kernel=linear ...................
# [CV]  epsilon=0.25, C=0.5, gamma=0.1, kernel=linear, score=-5.19108057738, total=  47.2s
# [CV] epsilon=0.25, C=0.5, gamma=0.15, kernel=linear ..................
# [CV]  epsilon=0.25, C=0.5, gamma=0.15, kernel=linear, score=-5.05254373054, total= 1.1min
# [CV] epsilon=0.25, C=0.5, gamma=0.15, kernel=linear ..................
# [CV]  epsilon=0.25, C=0.5, gamma=0.15, kernel=linear, score=-5.02118960808, total=  53.2s
# [CV] epsilon=0.25, C=0.5, gamma=0.15, kernel=linear ..................
# [CV]  epsilon=0.25, C=0.5, gamma=0.15, kernel=linear, score=-5.19108057738, total=  47.2s
# [CV] epsilon=0.05, C=0.75, gamma=0.05, kernel=linear .................
# [CV]  epsilon=0.05, C=0.75, gamma=0.05, kernel=linear, score=-5.06417614361, total= 1.5min
# [CV] epsilon=0.05, C=0.75, gamma=0.05, kernel=linear .................
# [CV]  epsilon=0.05, C=0.75, gamma=0.05, kernel=linear, score=-5.04033230006, total= 1.2min
# [CV] epsilon=0.05, C=0.75, gamma=0.05, kernel=linear .................
# [CV]  epsilon=0.05, C=0.75, gamma=0.05, kernel=linear, score=-5.1549236631, total= 1.3min
# [CV] epsilon=0.05, C=0.75, gamma=0.1, kernel=linear ..................
# [CV]  epsilon=0.05, C=0.75, gamma=0.1, kernel=linear, score=-5.06417614361, total= 1.5min
# [CV] epsilon=0.05, C=0.75, gamma=0.1, kernel=linear ..................
# [CV]  epsilon=0.05, C=0.75, gamma=0.1, kernel=linear, score=-5.04033230006, total= 1.2min
# [CV] epsilon=0.05, C=0.75, gamma=0.1, kernel=linear ..................
# [CV]  epsilon=0.05, C=0.75, gamma=0.1, kernel=linear, score=-5.1549236631, total= 1.3min
# [CV] epsilon=0.05, C=0.75, gamma=0.15, kernel=linear .................
# [CV]  epsilon=0.05, C=0.75, gamma=0.15, kernel=linear, score=-5.06417614361, total= 1.5min
# [CV] epsilon=0.05, C=0.75, gamma=0.15, kernel=linear .................
# [CV]  epsilon=0.05, C=0.75, gamma=0.15, kernel=linear, score=-5.04033230006, total= 1.2min
# [CV] epsilon=0.05, C=0.75, gamma=0.15, kernel=linear .................
# [CV]  epsilon=0.05, C=0.75, gamma=0.15, kernel=linear, score=-5.1549236631, total= 1.3min
# [CV] epsilon=0.1, C=0.75, gamma=0.05, kernel=linear ..................
# [CV]  epsilon=0.1, C=0.75, gamma=0.05, kernel=linear, score=-5.0667917065, total= 1.2min
# [CV] epsilon=0.1, C=0.75, gamma=0.05, kernel=linear ..................
# [CV]  epsilon=0.1, C=0.75, gamma=0.05, kernel=linear, score=-5.05580464161, total= 1.3min
# [CV] epsilon=0.1, C=0.75, gamma=0.05, kernel=linear ..................
# [CV]  epsilon=0.1, C=0.75, gamma=0.05, kernel=linear, score=-5.1347906116, total= 1.4min
# [CV] epsilon=0.1, C=0.75, gamma=0.1, kernel=linear ...................
# [CV]  epsilon=0.1, C=0.75, gamma=0.1, kernel=linear, score=-5.0667917065, total= 1.2min
# [CV] epsilon=0.1, C=0.75, gamma=0.1, kernel=linear ...................
# [CV]  epsilon=0.1, C=0.75, gamma=0.1, kernel=linear, score=-5.05580464161, total= 1.3min
# [CV] epsilon=0.1, C=0.75, gamma=0.1, kernel=linear ...................
# [CV]  epsilon=0.1, C=0.75, gamma=0.1, kernel=linear, score=-5.1347906116, total= 1.4min
# [CV] epsilon=0.1, C=0.75, gamma=0.15, kernel=linear ..................
# [CV]  epsilon=0.1, C=0.75, gamma=0.15, kernel=linear, score=-5.0667917065, total= 1.2min
# [CV] epsilon=0.1, C=0.75, gamma=0.15, kernel=linear ..................
# [CV]  epsilon=0.1, C=0.75, gamma=0.15, kernel=linear, score=-5.05580464161, total= 1.3min
# [CV] epsilon=0.1, C=0.75, gamma=0.15, kernel=linear ..................
# [CV]  epsilon=0.1, C=0.75, gamma=0.15, kernel=linear, score=-5.1347906116, total= 1.4min
# [CV] epsilon=0.15, C=0.75, gamma=0.05, kernel=linear .................
# [CV]  epsilon=0.15, C=0.75, gamma=0.05, kernel=linear, score=-5.05115952777, total= 1.2min
# [CV] epsilon=0.15, C=0.75, gamma=0.05, kernel=linear .................
# [CV]  epsilon=0.15, C=0.75, gamma=0.05, kernel=linear, score=-5.02736952876, total= 1.4min
# [CV] epsilon=0.15, C=0.75, gamma=0.05, kernel=linear .................
# [CV]  epsilon=0.15, C=0.75, gamma=0.05, kernel=linear, score=-5.19819787548, total= 1.5min
# [CV] epsilon=0.15, C=0.75, gamma=0.1, kernel=linear ..................
# [CV]  epsilon=0.15, C=0.75, gamma=0.1, kernel=linear, score=-5.05115952777, total= 1.2min
# [CV] epsilon=0.15, C=0.75, gamma=0.1, kernel=linear ..................
# [CV]  epsilon=0.15, C=0.75, gamma=0.1, kernel=linear, score=-5.02736952876, total= 1.4min
# [CV] epsilon=0.15, C=0.75, gamma=0.1, kernel=linear ..................
# [CV]  epsilon=0.15, C=0.75, gamma=0.1, kernel=linear, score=-5.19819787548, total= 1.4min
# [CV] epsilon=0.15, C=0.75, gamma=0.15, kernel=linear .................
# [CV]  epsilon=0.15, C=0.75, gamma=0.15, kernel=linear, score=-5.05115952777, total= 1.2min
# [CV] epsilon=0.15, C=0.75, gamma=0.15, kernel=linear .................
# [CV]  epsilon=0.15, C=0.75, gamma=0.15, kernel=linear, score=-5.02736952876, total= 1.4min
# [CV] epsilon=0.15, C=0.75, gamma=0.15, kernel=linear .................
# [CV]  epsilon=0.15, C=0.75, gamma=0.15, kernel=linear, score=-5.19819787548, total= 1.4min
# [CV] epsilon=0.2, C=0.75, gamma=0.05, kernel=linear ..................
# [CV]  epsilon=0.2, C=0.75, gamma=0.05, kernel=linear, score=-5.01645648366, total= 1.1min
# [CV] epsilon=0.2, C=0.75, gamma=0.05, kernel=linear ..................
# [CV]  epsilon=0.2, C=0.75, gamma=0.05, kernel=linear, score=-5.04633616325, total= 1.4min
# [CV] epsilon=0.2, C=0.75, gamma=0.05, kernel=linear ..................
# [CV]  epsilon=0.2, C=0.75, gamma=0.05, kernel=linear, score=-5.21531811301, total= 1.2min
# [CV] epsilon=0.2, C=0.75, gamma=0.1, kernel=linear ...................
# [CV]  epsilon=0.2, C=0.75, gamma=0.1, kernel=linear, score=-5.01645648366, total= 1.1min
# [CV] epsilon=0.2, C=0.75, gamma=0.1, kernel=linear ...................
# [CV]  epsilon=0.2, C=0.75, gamma=0.1, kernel=linear, score=-5.04633616325, total= 1.4min
# [CV] epsilon=0.2, C=0.75, gamma=0.1, kernel=linear ...................
# [CV]  epsilon=0.2, C=0.75, gamma=0.1, kernel=linear, score=-5.21531811301, total= 1.2min
# [CV] epsilon=0.2, C=0.75, gamma=0.15, kernel=linear ..................
# [CV]  epsilon=0.2, C=0.75, gamma=0.15, kernel=linear, score=-5.01645648366, total= 1.1min
# [CV] epsilon=0.2, C=0.75, gamma=0.15, kernel=linear ..................
# [CV]  epsilon=0.2, C=0.75, gamma=0.15, kernel=linear, score=-5.04633616325, total= 1.4min
# [CV] epsilon=0.2, C=0.75, gamma=0.15, kernel=linear ..................
# [CV]  epsilon=0.2, C=0.75, gamma=0.15, kernel=linear, score=-5.21531811301, total= 1.2min
# [CV] epsilon=0.25, C=0.75, gamma=0.05, kernel=linear .................
# [CV]  epsilon=0.25, C=0.75, gamma=0.05, kernel=linear, score=-5.04872776933, total= 1.2min
# [CV] epsilon=0.25, C=0.75, gamma=0.05, kernel=linear .................
# [CV]  epsilon=0.25, C=0.75, gamma=0.05, kernel=linear, score=-5.03023017778, total= 1.3min
# [CV] epsilon=0.25, C=0.75, gamma=0.05, kernel=linear .................
# [CV]  epsilon=0.25, C=0.75, gamma=0.05, kernel=linear, score=-5.16944253128, total= 1.6min
# [CV] epsilon=0.25, C=0.75, gamma=0.1, kernel=linear ..................
# [CV]  epsilon=0.25, C=0.75, gamma=0.1, kernel=linear, score=-5.04872776933, total= 1.2min
# [CV] epsilon=0.25, C=0.75, gamma=0.1, kernel=linear ..................
# [CV]  epsilon=0.25, C=0.75, gamma=0.1, kernel=linear, score=-5.03023017778, total= 1.3min
# [CV] epsilon=0.25, C=0.75, gamma=0.1, kernel=linear ..................
# [CV]  epsilon=0.25, C=0.75, gamma=0.1, kernel=linear, score=-5.16944253128, total= 1.5min
# [CV] epsilon=0.25, C=0.75, gamma=0.15, kernel=linear .................
# [CV]  epsilon=0.25, C=0.75, gamma=0.15, kernel=linear, score=-5.04872776933, total= 1.2min
# [CV] epsilon=0.25, C=0.75, gamma=0.15, kernel=linear .................
# [CV]  epsilon=0.25, C=0.75, gamma=0.15, kernel=linear, score=-5.03023017778, total= 1.3min
# [CV] epsilon=0.25, C=0.75, gamma=0.15, kernel=linear .................
# [CV]  epsilon=0.25, C=0.75, gamma=0.15, kernel=linear, score=-5.16944253128, total= 1.5min
# [CV] epsilon=0.05, C=1.0, gamma=0.05, kernel=linear ..................
# [CV]  epsilon=0.05, C=1.0, gamma=0.05, kernel=linear, score=-5.04664557544, total= 1.7min
# [CV] epsilon=0.05, C=1.0, gamma=0.05, kernel=linear ..................
# [CV]  epsilon=0.05, C=1.0, gamma=0.05, kernel=linear, score=-5.09364022642, total= 2.1min
# [CV] epsilon=0.05, C=1.0, gamma=0.05, kernel=linear ..................
# [CV]  epsilon=0.05, C=1.0, gamma=0.05, kernel=linear, score=-5.14427055177, total= 2.4min
# [CV] epsilon=0.05, C=1.0, gamma=0.1, kernel=linear ...................
# [CV]  epsilon=0.05, C=1.0, gamma=0.1, kernel=linear, score=-5.04664557544, total= 1.7min
# [CV] epsilon=0.05, C=1.0, gamma=0.1, kernel=linear ...................
# [CV]  epsilon=0.05, C=1.0, gamma=0.1, kernel=linear, score=-5.09364022642, total= 2.1min
# [CV] epsilon=0.05, C=1.0, gamma=0.1, kernel=linear ...................
# [CV]  epsilon=0.05, C=1.0, gamma=0.1, kernel=linear, score=-5.14427055177, total= 2.4min
# [CV] epsilon=0.05, C=1.0, gamma=0.15, kernel=linear ..................
# [CV]  epsilon=0.05, C=1.0, gamma=0.15, kernel=linear, score=-5.04664557544, total= 1.7min
# [CV] epsilon=0.05, C=1.0, gamma=0.15, kernel=linear ..................
# [CV]  epsilon=0.05, C=1.0, gamma=0.15, kernel=linear, score=-5.09364022642, total= 2.1min
# [CV] epsilon=0.05, C=1.0, gamma=0.15, kernel=linear ..................
# [CV]  epsilon=0.05, C=1.0, gamma=0.15, kernel=linear, score=-5.14427055177, total= 2.4min
# [CV] epsilon=0.1, C=1.0, gamma=0.05, kernel=linear ...................
# [CV]  epsilon=0.1, C=1.0, gamma=0.05, kernel=linear, score=-5.05197826325, total= 1.8min
# [CV] epsilon=0.1, C=1.0, gamma=0.05, kernel=linear ...................
# [CV]  epsilon=0.1, C=1.0, gamma=0.05, kernel=linear, score=-5.04277119993, total= 1.5min
# [CV] epsilon=0.1, C=1.0, gamma=0.05, kernel=linear ...................
# [CV]  epsilon=0.1, C=1.0, gamma=0.05, kernel=linear, score=-5.16082533826, total= 2.0min
# [CV] epsilon=0.1, C=1.0, gamma=0.1, kernel=linear ....................
# [CV]  epsilon=0.1, C=1.0, gamma=0.1, kernel=linear, score=-5.05197826325, total= 1.8min
# [CV] epsilon=0.1, C=1.0, gamma=0.1, kernel=linear ....................
# [CV]  epsilon=0.1, C=1.0, gamma=0.1, kernel=linear, score=-5.04277119993, total= 1.5min
# [CV] epsilon=0.1, C=1.0, gamma=0.1, kernel=linear ....................
# [CV]  epsilon=0.1, C=1.0, gamma=0.1, kernel=linear, score=-5.16082533826, total= 2.0min
# [CV] epsilon=0.1, C=1.0, gamma=0.15, kernel=linear ...................
# [CV]  epsilon=0.1, C=1.0, gamma=0.15, kernel=linear, score=-5.05197826325, total= 1.8min
# [CV] epsilon=0.1, C=1.0, gamma=0.15, kernel=linear ...................
# [CV]  epsilon=0.1, C=1.0, gamma=0.15, kernel=linear, score=-5.04277119993, total= 1.5min
# [CV] epsilon=0.1, C=1.0, gamma=0.15, kernel=linear ...................
# [CV]  epsilon=0.1, C=1.0, gamma=0.15, kernel=linear, score=-5.16082533826, total= 2.0min
# [CV] epsilon=0.15, C=1.0, gamma=0.05, kernel=linear ..................
# [CV]  epsilon=0.15, C=1.0, gamma=0.05, kernel=linear, score=-5.05157484517, total= 1.5min
# [CV] epsilon=0.15, C=1.0, gamma=0.05, kernel=linear ..................
# [CV]  epsilon=0.15, C=1.0, gamma=0.05, kernel=linear, score=-5.07591780481, total= 2.0min
# [CV] epsilon=0.15, C=1.0, gamma=0.05, kernel=linear ..................
# [CV]  epsilon=0.15, C=1.0, gamma=0.05, kernel=linear, score=-5.1598910998, total= 1.9min
# [CV] epsilon=0.15, C=1.0, gamma=0.1, kernel=linear ...................
# [CV]  epsilon=0.15, C=1.0, gamma=0.1, kernel=linear, score=-5.05157484517, total= 1.5min
# [CV] epsilon=0.15, C=1.0, gamma=0.1, kernel=linear ...................
# [CV]  epsilon=0.15, C=1.0, gamma=0.1, kernel=linear, score=-5.07591780481, total= 1.9min
# [CV] epsilon=0.15, C=1.0, gamma=0.1, kernel=linear ...................
# [CV]  epsilon=0.15, C=1.0, gamma=0.1, kernel=linear, score=-5.1598910998, total= 1.9min
# [CV] epsilon=0.15, C=1.0, gamma=0.15, kernel=linear ..................
# [CV]  epsilon=0.15, C=1.0, gamma=0.15, kernel=linear, score=-5.05157484517, total= 1.5min
# [CV] epsilon=0.15, C=1.0, gamma=0.15, kernel=linear ..................
# [CV]  epsilon=0.15, C=1.0, gamma=0.15, kernel=linear, score=-5.07591780481, total= 2.0min
# [CV] epsilon=0.15, C=1.0, gamma=0.15, kernel=linear ..................
# [CV]  epsilon=0.15, C=1.0, gamma=0.15, kernel=linear, score=-5.1598910998, total= 1.9min
# [CV] epsilon=0.2, C=1.0, gamma=0.05, kernel=linear ...................
# [CV]  epsilon=0.2, C=1.0, gamma=0.05, kernel=linear, score=-5.04253097008, total= 1.8min
# [CV] epsilon=0.2, C=1.0, gamma=0.05, kernel=linear ...................
# [CV]  epsilon=0.2, C=1.0, gamma=0.05, kernel=linear, score=-5.06240735204, total= 2.6min
# [CV] epsilon=0.2, C=1.0, gamma=0.05, kernel=linear ...................
# [CV]  epsilon=0.2, C=1.0, gamma=0.05, kernel=linear, score=-5.12044289447, total= 1.9min
# [CV] epsilon=0.2, C=1.0, gamma=0.1, kernel=linear ....................
# [CV]  epsilon=0.2, C=1.0, gamma=0.1, kernel=linear, score=-5.04253097008, total= 1.9min
# [CV] epsilon=0.2, C=1.0, gamma=0.1, kernel=linear ....................
# [CV]  epsilon=0.2, C=1.0, gamma=0.1, kernel=linear, score=-5.06240735204, total= 2.7min
# [CV] epsilon=0.2, C=1.0, gamma=0.1, kernel=linear ....................
# [CV]  epsilon=0.2, C=1.0, gamma=0.1, kernel=linear, score=-5.12044289447, total= 1.9min
# [CV] epsilon=0.2, C=1.0, gamma=0.15, kernel=linear ...................
# [CV]  epsilon=0.2, C=1.0, gamma=0.15, kernel=linear, score=-5.04253097008, total= 1.9min
# [CV] epsilon=0.2, C=1.0, gamma=0.15, kernel=linear ...................
# [CV]  epsilon=0.2, C=1.0, gamma=0.15, kernel=linear, score=-5.06240735204, total= 2.6min
# [CV] epsilon=0.2, C=1.0, gamma=0.15, kernel=linear ...................
# [CV]  epsilon=0.2, C=1.0, gamma=0.15, kernel=linear, score=-5.12044289447, total= 1.8min
# [CV] epsilon=0.25, C=1.0, gamma=0.05, kernel=linear ..................
# [CV]  epsilon=0.25, C=1.0, gamma=0.05, kernel=linear, score=-5.08599401774, total= 1.5min
# [CV] epsilon=0.25, C=1.0, gamma=0.05, kernel=linear ..................
# [CV]  epsilon=0.25, C=1.0, gamma=0.05, kernel=linear, score=-5.00953970721, total= 1.7min
# [CV] epsilon=0.25, C=1.0, gamma=0.05, kernel=linear ..................
# [CV]  epsilon=0.25, C=1.0, gamma=0.05, kernel=linear, score=-5.11770074359, total= 1.9min
# [CV] epsilon=0.25, C=1.0, gamma=0.1, kernel=linear ...................
# [CV]  epsilon=0.25, C=1.0, gamma=0.1, kernel=linear, score=-5.08599401774, total= 1.5min
# [CV] epsilon=0.25, C=1.0, gamma=0.1, kernel=linear ...................
# [CV]  epsilon=0.25, C=1.0, gamma=0.1, kernel=linear, score=-5.00953970721, total= 1.7min
# [CV] epsilon=0.25, C=1.0, gamma=0.1, kernel=linear ...................
# [CV]  epsilon=0.25, C=1.0, gamma=0.1, kernel=linear, score=-5.11770074359, total= 1.9min
# [CV] epsilon=0.25, C=1.0, gamma=0.15, kernel=linear ..................
# [CV]  epsilon=0.25, C=1.0, gamma=0.15, kernel=linear, score=-5.08599401774, total= 1.5min
# [CV] epsilon=0.25, C=1.0, gamma=0.15, kernel=linear ..................
# [CV]  epsilon=0.25, C=1.0, gamma=0.15, kernel=linear, score=-5.00953970721, total= 1.7min
# [CV] epsilon=0.25, C=1.0, gamma=0.15, kernel=linear ..................
# [CV]  epsilon=0.25, C=1.0, gamma=0.15, kernel=linear, score=-5.11770074359, total= 1.8min
# [Parallel(n_jobs=1)]: Done 180 out of 180 | elapsed: 204.3min finished
# LINEAR:
# (-5.067156303134736, {'epsilon': 0.05, 'C': 0.25, 'gamma': 0.05, 'kernel': 'linear'})
# (-5.067156303134736, {'epsilon': 0.05, 'C': 0.25, 'gamma': 0.1, 'kernel': 'linear'})
# (-5.067156303134736, {'epsilon': 0.05, 'C': 0.25, 'gamma': 0.15000000000000002, 'kernel': 'linear'})
# (-5.09572079204289, {'epsilon': 0.1, 'C': 0.25, 'gamma': 0.05, 'kernel': 'linear'})
# (-5.09572079204289, {'epsilon': 0.1, 'C': 0.25, 'gamma': 0.1, 'kernel': 'linear'})
# (-5.09572079204289, {'epsilon': 0.1, 'C': 0.25, 'gamma': 0.15000000000000002, 'kernel': 'linear'})
# (-5.074937338580171, {'epsilon': 0.15000000000000002, 'C': 0.25, 'gamma': 0.05, 'kernel': 'linear'})
# (-5.074937338580171, {'epsilon': 0.15000000000000002, 'C': 0.25, 'gamma': 0.1, 'kernel': 'linear'})
# (-5.074937338580171, {'epsilon': 0.15000000000000002, 'C': 0.25, 'gamma': 0.15000000000000002, 'kernel': 'linear'})
# (-5.080948342264042, {'epsilon': 0.2, 'C': 0.25, 'gamma': 0.05, 'kernel': 'linear'})
# (-5.080948342264042, {'epsilon': 0.2, 'C': 0.25, 'gamma': 0.1, 'kernel': 'linear'})
# (-5.080948342264042, {'epsilon': 0.2, 'C': 0.25, 'gamma': 0.15000000000000002, 'kernel': 'linear'})
# (-5.087300818063407, {'epsilon': 0.25, 'C': 0.25, 'gamma': 0.05, 'kernel': 'linear'})
# (-5.087300818063407, {'epsilon': 0.25, 'C': 0.25, 'gamma': 0.1, 'kernel': 'linear'})
# (-5.087300818063407, {'epsilon': 0.25, 'C': 0.25, 'gamma': 0.15000000000000002, 'kernel': 'linear'})
# (-5.090086648674, {'epsilon': 0.05, 'C': 0.5, 'gamma': 0.05, 'kernel': 'linear'})
# (-5.090086648674, {'epsilon': 0.05, 'C': 0.5, 'gamma': 0.1, 'kernel': 'linear'})
# (-5.090086648674, {'epsilon': 0.05, 'C': 0.5, 'gamma': 0.15000000000000002, 'kernel': 'linear'})
# (-5.112478414184519, {'epsilon': 0.1, 'C': 0.5, 'gamma': 0.05, 'kernel': 'linear'})
# (-5.112478414184519, {'epsilon': 0.1, 'C': 0.5, 'gamma': 0.1, 'kernel': 'linear'})
# (-5.112478414184519, {'epsilon': 0.1, 'C': 0.5, 'gamma': 0.15000000000000002, 'kernel': 'linear'})
# (-5.122654108305557, {'epsilon': 0.15000000000000002, 'C': 0.5, 'gamma': 0.05, 'kernel': 'linear'})
# (-5.122654108305557, {'epsilon': 0.15000000000000002, 'C': 0.5, 'gamma': 0.1, 'kernel': 'linear'})
# (-5.122654108305557, {'epsilon': 0.15000000000000002, 'C': 0.5, 'gamma': 0.15000000000000002, 'kernel': 'linear'})
# (-5.102681073357108, {'epsilon': 0.2, 'C': 0.5, 'gamma': 0.05, 'kernel': 'linear'})
# (-5.102681073357108, {'epsilon': 0.2, 'C': 0.5, 'gamma': 0.1, 'kernel': 'linear'})
# (-5.102681073357108, {'epsilon': 0.2, 'C': 0.5, 'gamma': 0.15000000000000002, 'kernel': 'linear'})
# (-5.088271305332943, {'epsilon': 0.25, 'C': 0.5, 'gamma': 0.05, 'kernel': 'linear'})
# (-5.088271305332943, {'epsilon': 0.25, 'C': 0.5, 'gamma': 0.1, 'kernel': 'linear'})
# (-5.088271305332943, {'epsilon': 0.25, 'C': 0.5, 'gamma': 0.15000000000000002, 'kernel': 'linear'})
# (-5.086477368922866, {'epsilon': 0.05, 'C': 0.75, 'gamma': 0.05, 'kernel': 'linear'})
# (-5.086477368922866, {'epsilon': 0.05, 'C': 0.75, 'gamma': 0.1, 'kernel': 'linear'})
# (-5.086477368922866, {'epsilon': 0.05, 'C': 0.75, 'gamma': 0.15000000000000002, 'kernel': 'linear'})
# (-5.085795653236342, {'epsilon': 0.1, 'C': 0.75, 'gamma': 0.05, 'kernel': 'linear'})
# (-5.085795653236342, {'epsilon': 0.1, 'C': 0.75, 'gamma': 0.1, 'kernel': 'linear'})
# (-5.085795653236342, {'epsilon': 0.1, 'C': 0.75, 'gamma': 0.15000000000000002, 'kernel': 'linear'})
# (-5.092242310666944, {'epsilon': 0.15000000000000002, 'C': 0.75, 'gamma': 0.05, 'kernel': 'linear'})
# (-5.092242310666944, {'epsilon': 0.15000000000000002, 'C': 0.75, 'gamma': 0.1, 'kernel': 'linear'})
# (-5.092242310666944, {'epsilon': 0.15000000000000002, 'C': 0.75, 'gamma': 0.15000000000000002, 'kernel': 'linear'})
# (-5.092703586639257, {'epsilon': 0.2, 'C': 0.75, 'gamma': 0.05, 'kernel': 'linear'})
# (-5.092703586639257, {'epsilon': 0.2, 'C': 0.75, 'gamma': 0.1, 'kernel': 'linear'})
# (-5.092703586639257, {'epsilon': 0.2, 'C': 0.75, 'gamma': 0.15000000000000002, 'kernel': 'linear'})
# (-5.082800159464722, {'epsilon': 0.25, 'C': 0.75, 'gamma': 0.05, 'kernel': 'linear'})
# (-5.082800159464722, {'epsilon': 0.25, 'C': 0.75, 'gamma': 0.1, 'kernel': 'linear'})
# (-5.082800159464722, {'epsilon': 0.25, 'C': 0.75, 'gamma': 0.15000000000000002, 'kernel': 'linear'})
# (-5.094852117874777, {'epsilon': 0.05, 'C': 1.0, 'gamma': 0.05, 'kernel': 'linear'})
# (-5.094852117874777, {'epsilon': 0.05, 'C': 1.0, 'gamma': 0.1, 'kernel': 'linear'})
# (-5.094852117874777, {'epsilon': 0.05, 'C': 1.0, 'gamma': 0.15000000000000002, 'kernel': 'linear'})
# (-5.085191600482025, {'epsilon': 0.1, 'C': 1.0, 'gamma': 0.05, 'kernel': 'linear'})
# (-5.085191600482025, {'epsilon': 0.1, 'C': 1.0, 'gamma': 0.1, 'kernel': 'linear'})
# (-5.085191600482025, {'epsilon': 0.1, 'C': 1.0, 'gamma': 0.15000000000000002, 'kernel': 'linear'})
# (-5.0957945832609335, {'epsilon': 0.15000000000000002, 'C': 1.0, 'gamma': 0.05, 'kernel': 'linear'})
# (-5.0957945832609335, {'epsilon': 0.15000000000000002, 'C': 1.0, 'gamma': 0.1, 'kernel': 'linear'})
# (-5.0957945832609335, {'epsilon': 0.15000000000000002, 'C': 1.0, 'gamma': 0.15000000000000002, 'kernel': 'linear'})
# (-5.075127072198659, {'epsilon': 0.2, 'C': 1.0, 'gamma': 0.05, 'kernel': 'linear'})
# (-5.075127072198659, {'epsilon': 0.2, 'C': 1.0, 'gamma': 0.1, 'kernel': 'linear'})
# (-5.075127072198659, {'epsilon': 0.2, 'C': 1.0, 'gamma': 0.15000000000000002, 'kernel': 'linear'})
# (-5.071078156177312, {'epsilon': 0.25, 'C': 1.0, 'gamma': 0.05, 'kernel': 'linear'})
# (-5.071078156177312, {'epsilon': 0.25, 'C': 1.0, 'gamma': 0.1, 'kernel': 'linear'})
# (-5.071078156177312, {'epsilon': 0.25, 'C': 1.0, 'gamma': 0.15000000000000002, 'kernel': 'linear'})
# Best: {'epsilon': 0.05, 'C': 0.25, 'gamma': 0.05, 'kernel': 'linear'}
# Fitting 3 folds for each of 60 candidates, totalling 180 fits
# [CV] epsilon=0.05, C=0.25, gamma=0.05, kernel=rbf ....................
# [CV]  epsilon=0.05, C=0.25, gamma=0.05, kernel=rbf, score=-5.642625, total=   0.6s
# [CV] epsilon=0.05, C=0.25, gamma=0.05, kernel=rbf ....................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.9s remaining:    0.0s
# [CV]  epsilon=0.05, C=0.25, gamma=0.05, kernel=rbf, score=-5.36426229508, total=   0.6s
# [CV] epsilon=0.05, C=0.25, gamma=0.05, kernel=rbf ....................
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    1.8s remaining:    0.0s
# [CV]  epsilon=0.05, C=0.25, gamma=0.05, kernel=rbf, score=-5.47363636364, total=   0.6s
# [CV] epsilon=0.05, C=0.25, gamma=0.1, kernel=rbf .....................
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    2.8s remaining:    0.0s
# [CV]  epsilon=0.05, C=0.25, gamma=0.1, kernel=rbf, score=-5.642625, total=   0.6s
# [CV] epsilon=0.05, C=0.25, gamma=0.1, kernel=rbf .....................
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    3.6s remaining:    0.0s
# [CV]  epsilon=0.05, C=0.25, gamma=0.1, kernel=rbf, score=-5.36426229508, total=   0.6s
# [CV] epsilon=0.05, C=0.25, gamma=0.1, kernel=rbf .....................
# [CV]  epsilon=0.05, C=0.25, gamma=0.1, kernel=rbf, score=-5.47363636364, total=   0.6s
# [CV] epsilon=0.05, C=0.25, gamma=0.15, kernel=rbf ....................
# [CV]  epsilon=0.05, C=0.25, gamma=0.15, kernel=rbf, score=-5.642625, total=   0.6s
# [CV] epsilon=0.05, C=0.25, gamma=0.15, kernel=rbf ....................
# [CV]  epsilon=0.05, C=0.25, gamma=0.15, kernel=rbf, score=-5.36426229508, total=   0.6s
# [CV] epsilon=0.05, C=0.25, gamma=0.15, kernel=rbf ....................
# [CV]  epsilon=0.05, C=0.25, gamma=0.15, kernel=rbf, score=-5.47363636364, total=   0.6s
# [CV] epsilon=0.1, C=0.25, gamma=0.05, kernel=rbf .....................
# [CV]  epsilon=0.1, C=0.25, gamma=0.05, kernel=rbf, score=-5.642875, total=   0.6s
# [CV] epsilon=0.1, C=0.25, gamma=0.05, kernel=rbf .....................
# [CV]  epsilon=0.1, C=0.25, gamma=0.05, kernel=rbf, score=-5.3653125033, total=   0.7s
# [CV] epsilon=0.1, C=0.25, gamma=0.05, kernel=rbf .....................
# [CV]  epsilon=0.1, C=0.25, gamma=0.05, kernel=rbf, score=-5.47632352941, total=   0.7s
# [CV] epsilon=0.1, C=0.25, gamma=0.1, kernel=rbf ......................
# [CV]  epsilon=0.1, C=0.25, gamma=0.1, kernel=rbf, score=-5.642875, total=   0.6s
# [CV] epsilon=0.1, C=0.25, gamma=0.1, kernel=rbf ......................
# [CV]  epsilon=0.1, C=0.25, gamma=0.1, kernel=rbf, score=-5.3653125, total=   0.6s
# [CV] epsilon=0.1, C=0.25, gamma=0.1, kernel=rbf ......................
# [CV]  epsilon=0.1, C=0.25, gamma=0.1, kernel=rbf, score=-5.47632352941, total=   0.6s
# [CV] epsilon=0.1, C=0.25, gamma=0.15, kernel=rbf .....................
# [CV]  epsilon=0.1, C=0.25, gamma=0.15, kernel=rbf, score=-5.642875, total=   0.6s
# [CV] epsilon=0.1, C=0.25, gamma=0.15, kernel=rbf .....................
# [CV]  epsilon=0.1, C=0.25, gamma=0.15, kernel=rbf, score=-5.3653125, total=   0.6s
# [CV] epsilon=0.1, C=0.25, gamma=0.15, kernel=rbf .....................
# [CV]  epsilon=0.1, C=0.25, gamma=0.15, kernel=rbf, score=-5.47632352941, total=   0.6s
# [CV] epsilon=0.15, C=0.25, gamma=0.05, kernel=rbf ....................
# [CV]  epsilon=0.15, C=0.25, gamma=0.05, kernel=rbf, score=-5.64135135135, total=   0.6s
# [CV] epsilon=0.15, C=0.25, gamma=0.05, kernel=rbf ....................
# [CV]  epsilon=0.15, C=0.25, gamma=0.05, kernel=rbf, score=-5.37304348132, total=   0.6s
# [CV] epsilon=0.15, C=0.25, gamma=0.05, kernel=rbf ....................
# [CV]  epsilon=0.15, C=0.25, gamma=0.05, kernel=rbf, score=-5.48352941487, total=   0.6s
# [CV] epsilon=0.15, C=0.25, gamma=0.1, kernel=rbf .....................
# [CV]  epsilon=0.15, C=0.25, gamma=0.1, kernel=rbf, score=-5.64135135135, total=   0.6s
# [CV] epsilon=0.15, C=0.25, gamma=0.1, kernel=rbf .....................
# [CV]  epsilon=0.15, C=0.25, gamma=0.1, kernel=rbf, score=-5.37304347826, total=   0.6s
# [CV] epsilon=0.15, C=0.25, gamma=0.1, kernel=rbf .....................
# [CV]  epsilon=0.15, C=0.25, gamma=0.1, kernel=rbf, score=-5.48352941176, total=   0.6s
# [CV] epsilon=0.15, C=0.25, gamma=0.15, kernel=rbf ....................
# [CV]  epsilon=0.15, C=0.25, gamma=0.15, kernel=rbf, score=-5.64135135135, total=   0.6s
# [CV] epsilon=0.15, C=0.25, gamma=0.15, kernel=rbf ....................
# [CV]  epsilon=0.15, C=0.25, gamma=0.15, kernel=rbf, score=-5.37304347826, total=   0.6s
# [CV] epsilon=0.15, C=0.25, gamma=0.15, kernel=rbf ....................
# [CV]  epsilon=0.15, C=0.25, gamma=0.15, kernel=rbf, score=-5.48352941176, total=   0.6s
# [CV] epsilon=0.2, C=0.25, gamma=0.05, kernel=rbf .....................
# [CV]  epsilon=0.2, C=0.25, gamma=0.05, kernel=rbf, score=-5.63428571429, total=   0.6s
# [CV] epsilon=0.2, C=0.25, gamma=0.05, kernel=rbf .....................
# [CV]  epsilon=0.2, C=0.25, gamma=0.05, kernel=rbf, score=-5.37672130641, total=   0.6s
# [CV] epsilon=0.2, C=0.25, gamma=0.05, kernel=rbf .....................
# [CV]  epsilon=0.2, C=0.25, gamma=0.05, kernel=rbf, score=-5.49602941487, total=   0.6s
# [CV] epsilon=0.2, C=0.25, gamma=0.1, kernel=rbf ......................
# [CV]  epsilon=0.2, C=0.25, gamma=0.1, kernel=rbf, score=-5.63428571429, total=   0.6s
# [CV] epsilon=0.2, C=0.25, gamma=0.1, kernel=rbf ......................
# [CV]  epsilon=0.2, C=0.25, gamma=0.1, kernel=rbf, score=-5.37672131148, total=   0.6s
# [CV] epsilon=0.2, C=0.25, gamma=0.1, kernel=rbf ......................
# [CV]  epsilon=0.2, C=0.25, gamma=0.1, kernel=rbf, score=-5.49602941176, total=   0.6s
# [CV] epsilon=0.2, C=0.25, gamma=0.15, kernel=rbf .....................
# [CV]  epsilon=0.2, C=0.25, gamma=0.15, kernel=rbf, score=-5.63428571429, total=   0.6s
# [CV] epsilon=0.2, C=0.25, gamma=0.15, kernel=rbf .....................
# [CV]  epsilon=0.2, C=0.25, gamma=0.15, kernel=rbf, score=-5.37672131148, total=   0.6s
# [CV] epsilon=0.2, C=0.25, gamma=0.15, kernel=rbf .....................
# [CV]  epsilon=0.2, C=0.25, gamma=0.15, kernel=rbf, score=-5.49602941176, total=   0.6s
# [CV] epsilon=0.25, C=0.25, gamma=0.05, kernel=rbf ....................
# [CV]  epsilon=0.25, C=0.25, gamma=0.05, kernel=rbf, score=-5.632, total=   0.6s
# [CV] epsilon=0.25, C=0.25, gamma=0.05, kernel=rbf ....................
# [CV]  epsilon=0.25, C=0.25, gamma=0.05, kernel=rbf, score=-5.37766667081, total=   0.6s
# [CV] epsilon=0.25, C=0.25, gamma=0.05, kernel=rbf ....................
# [CV]  epsilon=0.25, C=0.25, gamma=0.05, kernel=rbf, score=-5.51107692829, total=   0.6s
# [CV] epsilon=0.25, C=0.25, gamma=0.1, kernel=rbf .....................
# [CV]  epsilon=0.25, C=0.25, gamma=0.1, kernel=rbf, score=-5.632, total=   0.6s
# [CV] epsilon=0.25, C=0.25, gamma=0.1, kernel=rbf .....................
# [CV]  epsilon=0.25, C=0.25, gamma=0.1, kernel=rbf, score=-5.37766666667, total=   0.6s
# [CV] epsilon=0.25, C=0.25, gamma=0.1, kernel=rbf .....................
# [CV]  epsilon=0.25, C=0.25, gamma=0.1, kernel=rbf, score=-5.51107692308, total=   0.6s
# [CV] epsilon=0.25, C=0.25, gamma=0.15, kernel=rbf ....................
# [CV]  epsilon=0.25, C=0.25, gamma=0.15, kernel=rbf, score=-5.632, total=   0.6s
# [CV] epsilon=0.25, C=0.25, gamma=0.15, kernel=rbf ....................
# [CV]  epsilon=0.25, C=0.25, gamma=0.15, kernel=rbf, score=-5.37766666667, total=   0.6s
# [CV] epsilon=0.25, C=0.25, gamma=0.15, kernel=rbf ....................
# [CV]  epsilon=0.25, C=0.25, gamma=0.15, kernel=rbf, score=-5.51107692308, total=   0.6s
# [CV] epsilon=0.05, C=0.5, gamma=0.05, kernel=rbf .....................
# [CV]  epsilon=0.05, C=0.5, gamma=0.05, kernel=rbf, score=-5.63356164384, total=   0.6s
# [CV] epsilon=0.05, C=0.5, gamma=0.05, kernel=rbf .....................
# [CV]  epsilon=0.05, C=0.5, gamma=0.05, kernel=rbf, score=-5.37283185337, total=   0.6s
# [CV] epsilon=0.05, C=0.5, gamma=0.05, kernel=rbf .....................
# [CV]  epsilon=0.05, C=0.5, gamma=0.05, kernel=rbf, score=-5.4997561029, total=   0.6s
# [CV] epsilon=0.05, C=0.5, gamma=0.1, kernel=rbf ......................
# [CV]  epsilon=0.05, C=0.5, gamma=0.1, kernel=rbf, score=-5.63356164384, total=   0.6s
# [CV] epsilon=0.05, C=0.5, gamma=0.1, kernel=rbf ......................
# [CV]  epsilon=0.05, C=0.5, gamma=0.1, kernel=rbf, score=-5.37283185841, total=   0.6s
# [CV] epsilon=0.05, C=0.5, gamma=0.1, kernel=rbf ......................
# [CV]  epsilon=0.05, C=0.5, gamma=0.1, kernel=rbf, score=-5.49975609756, total=   0.6s
# [CV] epsilon=0.05, C=0.5, gamma=0.15, kernel=rbf .....................
# [CV]  epsilon=0.05, C=0.5, gamma=0.15, kernel=rbf, score=-5.63356164384, total=   0.6s
# [CV] epsilon=0.05, C=0.5, gamma=0.15, kernel=rbf .....................
# [CV]  epsilon=0.05, C=0.5, gamma=0.15, kernel=rbf, score=-5.37283185841, total=   0.6s
# [CV] epsilon=0.05, C=0.5, gamma=0.15, kernel=rbf .....................
# [CV]  epsilon=0.05, C=0.5, gamma=0.15, kernel=rbf, score=-5.49975609756, total=   0.6s
# [CV] epsilon=0.1, C=0.5, gamma=0.05, kernel=rbf ......................
# [CV]  epsilon=0.1, C=0.5, gamma=0.05, kernel=rbf, score=-5.63006802721, total=   0.6s
# [CV] epsilon=0.1, C=0.5, gamma=0.05, kernel=rbf ......................
# [CV]  epsilon=0.1, C=0.5, gamma=0.05, kernel=rbf, score=-5.37409836472, total=   0.6s
# [CV] epsilon=0.1, C=0.5, gamma=0.05, kernel=rbf ......................
# [CV]  epsilon=0.1, C=0.5, gamma=0.05, kernel=rbf, score=-5.50878049259, total=   0.6s
# [CV] epsilon=0.1, C=0.5, gamma=0.1, kernel=rbf .......................
# [CV]  epsilon=0.1, C=0.5, gamma=0.1, kernel=rbf, score=-5.63006802721, total=   0.6s
# [CV] epsilon=0.1, C=0.5, gamma=0.1, kernel=rbf .......................
# [CV]  epsilon=0.1, C=0.5, gamma=0.1, kernel=rbf, score=-5.37409836066, total=   0.6s
# [CV] epsilon=0.1, C=0.5, gamma=0.1, kernel=rbf .......................
# [CV]  epsilon=0.1, C=0.5, gamma=0.1, kernel=rbf, score=-5.5087804878, total=   0.6s
# [CV] epsilon=0.1, C=0.5, gamma=0.15, kernel=rbf ......................
# [CV]  epsilon=0.1, C=0.5, gamma=0.15, kernel=rbf, score=-5.63006802721, total=   0.6s
# [CV] epsilon=0.1, C=0.5, gamma=0.15, kernel=rbf ......................
# [CV]  epsilon=0.1, C=0.5, gamma=0.15, kernel=rbf, score=-5.37409836066, total=   0.6s
# [CV] epsilon=0.1, C=0.5, gamma=0.15, kernel=rbf ......................
# [CV]  epsilon=0.1, C=0.5, gamma=0.15, kernel=rbf, score=-5.5087804878, total=   0.6s
# [CV] epsilon=0.15, C=0.5, gamma=0.05, kernel=rbf .....................
# [CV]  epsilon=0.15, C=0.5, gamma=0.05, kernel=rbf, score=-5.63287671233, total=   0.6s
# [CV] epsilon=0.15, C=0.5, gamma=0.05, kernel=rbf .....................
# [CV]  epsilon=0.15, C=0.5, gamma=0.05, kernel=rbf, score=-5.3777777744, total=   0.6s
# [CV] epsilon=0.15, C=0.5, gamma=0.05, kernel=rbf .....................
# [CV]  epsilon=0.15, C=0.5, gamma=0.05, kernel=rbf, score=-5.51941176031, total=   0.6s
# [CV] epsilon=0.15, C=0.5, gamma=0.1, kernel=rbf ......................
# [CV]  epsilon=0.15, C=0.5, gamma=0.1, kernel=rbf, score=-5.63287671233, total=   0.6s
# [CV] epsilon=0.15, C=0.5, gamma=0.1, kernel=rbf ......................
# [CV]  epsilon=0.15, C=0.5, gamma=0.1, kernel=rbf, score=-5.37777777778, total=   0.6s
# [CV] epsilon=0.15, C=0.5, gamma=0.1, kernel=rbf ......................
# [CV]  epsilon=0.15, C=0.5, gamma=0.1, kernel=rbf, score=-5.51941176471, total=   0.6s
# [CV] epsilon=0.15, C=0.5, gamma=0.15, kernel=rbf .....................
# [CV]  epsilon=0.15, C=0.5, gamma=0.15, kernel=rbf, score=-5.63287671233, total=   0.6s
# [CV] epsilon=0.15, C=0.5, gamma=0.15, kernel=rbf .....................
# [CV]  epsilon=0.15, C=0.5, gamma=0.15, kernel=rbf, score=-5.37777777778, total=   0.6s
# [CV] epsilon=0.15, C=0.5, gamma=0.15, kernel=rbf .....................
# [CV]  epsilon=0.15, C=0.5, gamma=0.15, kernel=rbf, score=-5.51941176471, total=   0.6s
# [CV] epsilon=0.2, C=0.5, gamma=0.05, kernel=rbf ......................
# [CV]  epsilon=0.2, C=0.5, gamma=0.05, kernel=rbf, score=-5.63445945946, total=   0.6s
# [CV] epsilon=0.2, C=0.5, gamma=0.05, kernel=rbf ......................
# [CV]  epsilon=0.2, C=0.5, gamma=0.05, kernel=rbf, score=-5.37121951509, total=   0.6s
# [CV] epsilon=0.2, C=0.5, gamma=0.05, kernel=rbf ......................
# [CV]  epsilon=0.2, C=0.5, gamma=0.05, kernel=rbf, score=-5.51253968619, total=   0.6s
# [CV] epsilon=0.2, C=0.5, gamma=0.1, kernel=rbf .......................
# [CV]  epsilon=0.2, C=0.5, gamma=0.1, kernel=rbf, score=-5.63445945946, total=   0.6s
# [CV] epsilon=0.2, C=0.5, gamma=0.1, kernel=rbf .......................
# [CV]  epsilon=0.2, C=0.5, gamma=0.1, kernel=rbf, score=-5.3712195122, total=   0.6s
# [CV] epsilon=0.2, C=0.5, gamma=0.1, kernel=rbf .......................
# [CV]  epsilon=0.2, C=0.5, gamma=0.1, kernel=rbf, score=-5.51253968254, total=   0.6s
# [CV] epsilon=0.2, C=0.5, gamma=0.15, kernel=rbf ......................
# [CV]  epsilon=0.2, C=0.5, gamma=0.15, kernel=rbf, score=-5.63445945946, total=   0.6s
# [CV] epsilon=0.2, C=0.5, gamma=0.15, kernel=rbf ......................
# [CV]  epsilon=0.2, C=0.5, gamma=0.15, kernel=rbf, score=-5.3712195122, total=   0.6s
# ...
# [CV] epsilon=0.2, C=0.75, gamma=0.15, kernel=sigmoid .................
# [CV]  epsilon=0.2, C=0.75, gamma=0.15, kernel=sigmoid, score=-5.37, total=   0.5s
# [CV] epsilon=0.2, C=0.75, gamma=0.15, kernel=sigmoid .................
# [CV]  epsilon=0.2, C=0.75, gamma=0.15, kernel=sigmoid, score=-5.46, total=   0.5s
# [CV] epsilon=0.25, C=0.75, gamma=0.05, kernel=sigmoid ................
# [CV]  epsilon=0.25, C=0.75, gamma=0.05, kernel=sigmoid, score=-5.63, total=   0.5s
# [CV] epsilon=0.25, C=0.75, gamma=0.05, kernel=sigmoid ................
# [CV]  epsilon=0.25, C=0.75, gamma=0.05, kernel=sigmoid, score=-5.37, total=   0.5s
# [CV] epsilon=0.25, C=0.75, gamma=0.05, kernel=sigmoid ................
# [CV]  epsilon=0.25, C=0.75, gamma=0.05, kernel=sigmoid, score=-5.47, total=   0.5s
# [CV] epsilon=0.25, C=0.75, gamma=0.1, kernel=sigmoid .................
# [CV]  epsilon=0.25, C=0.75, gamma=0.1, kernel=sigmoid, score=-5.63, total=   0.5s
# [CV] epsilon=0.25, C=0.75, gamma=0.1, kernel=sigmoid .................
# [CV]  epsilon=0.25, C=0.75, gamma=0.1, kernel=sigmoid, score=-5.37, total=   0.5s
# [CV] epsilon=0.25, C=0.75, gamma=0.1, kernel=sigmoid .................
# [CV]  epsilon=0.25, C=0.75, gamma=0.1, kernel=sigmoid, score=-5.47, total=   0.5s
# [CV] epsilon=0.25, C=0.75, gamma=0.15, kernel=sigmoid ................
# [CV]  epsilon=0.25, C=0.75, gamma=0.15, kernel=sigmoid, score=-5.63, total=   0.5s
# [CV] epsilon=0.25, C=0.75, gamma=0.15, kernel=sigmoid ................
# [CV]  epsilon=0.25, C=0.75, gamma=0.15, kernel=sigmoid, score=-5.37, total=   0.5s
# [CV] epsilon=0.25, C=0.75, gamma=0.15, kernel=sigmoid ................
# [CV]  epsilon=0.25, C=0.75, gamma=0.15, kernel=sigmoid, score=-5.47, total=   0.5s
# [CV] epsilon=0.05, C=1.0, gamma=0.05, kernel=sigmoid .................
# [CV]  epsilon=0.05, C=1.0, gamma=0.05, kernel=sigmoid, score=-5.65, total=   0.5s
# [CV] epsilon=0.05, C=1.0, gamma=0.05, kernel=sigmoid .................
# [CV]  epsilon=0.05, C=1.0, gamma=0.05, kernel=sigmoid, score=-5.37, total=   0.5s
# [CV] epsilon=0.05, C=1.0, gamma=0.05, kernel=sigmoid .................
# [CV]  epsilon=0.05, C=1.0, gamma=0.05, kernel=sigmoid, score=-5.47, total=   0.5s
# [CV] epsilon=0.05, C=1.0, gamma=0.1, kernel=sigmoid ..................
# [CV]  epsilon=0.05, C=1.0, gamma=0.1, kernel=sigmoid, score=-5.65, total=   0.5s
# [CV] epsilon=0.05, C=1.0, gamma=0.1, kernel=sigmoid ..................
# [CV]  epsilon=0.05, C=1.0, gamma=0.1, kernel=sigmoid, score=-5.37, total=   0.5s
# [CV] epsilon=0.05, C=1.0, gamma=0.1, kernel=sigmoid ..................
# [CV]  epsilon=0.05, C=1.0, gamma=0.1, kernel=sigmoid, score=-5.47, total=   0.5s
# [CV] epsilon=0.05, C=1.0, gamma=0.15, kernel=sigmoid .................
# [CV]  epsilon=0.05, C=1.0, gamma=0.15, kernel=sigmoid, score=-5.65, total=   0.5s
# [CV] epsilon=0.05, C=1.0, gamma=0.15, kernel=sigmoid .................
# [CV]  epsilon=0.05, C=1.0, gamma=0.15, kernel=sigmoid, score=-5.37, total=   0.5s
# [CV] epsilon=0.05, C=1.0, gamma=0.15, kernel=sigmoid .................
# [CV]  epsilon=0.05, C=1.0, gamma=0.15, kernel=sigmoid, score=-5.47, total=   0.5s
# [CV] epsilon=0.1, C=1.0, gamma=0.05, kernel=sigmoid ..................
# [CV]  epsilon=0.1, C=1.0, gamma=0.05, kernel=sigmoid, score=-5.64, total=   0.5s
# [CV] epsilon=0.1, C=1.0, gamma=0.05, kernel=sigmoid ..................
# [CV]  epsilon=0.1, C=1.0, gamma=0.05, kernel=sigmoid, score=-5.37, total=   0.5s
# [CV] epsilon=0.1, C=1.0, gamma=0.05, kernel=sigmoid ..................
# [CV]  epsilon=0.1, C=1.0, gamma=0.05, kernel=sigmoid, score=-5.48, total=   0.5s
# [CV] epsilon=0.1, C=1.0, gamma=0.1, kernel=sigmoid ...................
# [CV]  epsilon=0.1, C=1.0, gamma=0.1, kernel=sigmoid, score=-5.64, total=   0.5s
# [CV] epsilon=0.1, C=1.0, gamma=0.1, kernel=sigmoid ...................
# [CV]  epsilon=0.1, C=1.0, gamma=0.1, kernel=sigmoid, score=-5.37, total=   0.5s
# [CV] epsilon=0.1, C=1.0, gamma=0.1, kernel=sigmoid ...................
# [CV]  epsilon=0.1, C=1.0, gamma=0.1, kernel=sigmoid, score=-5.48, total=   0.5s
# [CV] epsilon=0.1, C=1.0, gamma=0.15, kernel=sigmoid ..................
# [CV]  epsilon=0.1, C=1.0, gamma=0.15, kernel=sigmoid, score=-5.64, total=   0.5s
# [CV] epsilon=0.1, C=1.0, gamma=0.15, kernel=sigmoid ..................
# [CV]  epsilon=0.1, C=1.0, gamma=0.15, kernel=sigmoid, score=-5.37, total=   0.5s
# [CV] epsilon=0.1, C=1.0, gamma=0.15, kernel=sigmoid ..................
# [CV]  epsilon=0.1, C=1.0, gamma=0.15, kernel=sigmoid, score=-5.48, total=   0.5s
# [CV] epsilon=0.15, C=1.0, gamma=0.05, kernel=sigmoid .................
# [CV]  epsilon=0.15, C=1.0, gamma=0.05, kernel=sigmoid, score=-5.65, total=   0.5s
# [CV] epsilon=0.15, C=1.0, gamma=0.05, kernel=sigmoid .................
# [CV]  epsilon=0.15, C=1.0, gamma=0.05, kernel=sigmoid, score=-5.37, total=   0.5s
# [CV] epsilon=0.15, C=1.0, gamma=0.05, kernel=sigmoid .................
# [CV]  epsilon=0.15, C=1.0, gamma=0.05, kernel=sigmoid, score=-5.47, total=   0.5s
# [CV] epsilon=0.15, C=1.0, gamma=0.1, kernel=sigmoid ..................
# [CV]  epsilon=0.15, C=1.0, gamma=0.1, kernel=sigmoid, score=-5.65, total=   0.5s
# [CV] epsilon=0.15, C=1.0, gamma=0.1, kernel=sigmoid ..................
# [CV]  epsilon=0.15, C=1.0, gamma=0.1, kernel=sigmoid, score=-5.37, total=   0.5s
# [CV] epsilon=0.15, C=1.0, gamma=0.1, kernel=sigmoid ..................
# [CV]  epsilon=0.15, C=1.0, gamma=0.1, kernel=sigmoid, score=-5.47, total=   0.5s
# [CV] epsilon=0.15, C=1.0, gamma=0.15, kernel=sigmoid .................
# [CV]  epsilon=0.15, C=1.0, gamma=0.15, kernel=sigmoid, score=-5.65, total=   0.5s
# [CV] epsilon=0.15, C=1.0, gamma=0.15, kernel=sigmoid .................
# [CV]  epsilon=0.15, C=1.0, gamma=0.15, kernel=sigmoid, score=-5.37, total=   0.5s
# [CV] epsilon=0.15, C=1.0, gamma=0.15, kernel=sigmoid .................
# [CV]  epsilon=0.15, C=1.0, gamma=0.15, kernel=sigmoid, score=-5.47, total=   0.5s
# [CV] epsilon=0.2, C=1.0, gamma=0.05, kernel=sigmoid ..................
# [CV]  epsilon=0.2, C=1.0, gamma=0.05, kernel=sigmoid, score=-5.66, total=   0.5s
# [CV] epsilon=0.2, C=1.0, gamma=0.05, kernel=sigmoid ..................
# [CV]  epsilon=0.2, C=1.0, gamma=0.05, kernel=sigmoid, score=-5.37, total=   0.5s
# [CV] epsilon=0.2, C=1.0, gamma=0.05, kernel=sigmoid ..................
# [CV]  epsilon=0.2, C=1.0, gamma=0.05, kernel=sigmoid, score=-5.46, total=   0.5s
# [CV] epsilon=0.2, C=1.0, gamma=0.1, kernel=sigmoid ...................
# [CV]  epsilon=0.2, C=1.0, gamma=0.1, kernel=sigmoid, score=-5.66, total=   0.5s
# [CV] epsilon=0.2, C=1.0, gamma=0.1, kernel=sigmoid ...................
# [CV]  epsilon=0.2, C=1.0, gamma=0.1, kernel=sigmoid, score=-5.37, total=   0.5s
# [CV] epsilon=0.2, C=1.0, gamma=0.1, kernel=sigmoid ...................
# [CV]  epsilon=0.2, C=1.0, gamma=0.1, kernel=sigmoid, score=-5.46, total=   0.5s
# [CV] epsilon=0.2, C=1.0, gamma=0.15, kernel=sigmoid ..................
# [CV]  epsilon=0.2, C=1.0, gamma=0.15, kernel=sigmoid, score=-5.66, total=   0.5s
# [CV] epsilon=0.2, C=1.0, gamma=0.15, kernel=sigmoid ..................
# [CV]  epsilon=0.2, C=1.0, gamma=0.15, kernel=sigmoid, score=-5.37, total=   0.5s
# [CV] epsilon=0.2, C=1.0, gamma=0.15, kernel=sigmoid ..................
# [CV]  epsilon=0.2, C=1.0, gamma=0.15, kernel=sigmoid, score=-5.46, total=   0.5s
# [CV] epsilon=0.25, C=1.0, gamma=0.05, kernel=sigmoid .................
# [CV]  epsilon=0.25, C=1.0, gamma=0.05, kernel=sigmoid, score=-5.63, total=   0.5s
# [CV] epsilon=0.25, C=1.0, gamma=0.05, kernel=sigmoid .................
# [CV]  epsilon=0.25, C=1.0, gamma=0.05, kernel=sigmoid, score=-5.37, total=   0.5s
# [CV] epsilon=0.25, C=1.0, gamma=0.05, kernel=sigmoid .................
# [CV]  epsilon=0.25, C=1.0, gamma=0.05, kernel=sigmoid, score=-5.47, total=   0.5s
# [CV] epsilon=0.25, C=1.0, gamma=0.1, kernel=sigmoid ..................
# [CV]  epsilon=0.25, C=1.0, gamma=0.1, kernel=sigmoid, score=-5.63, total=   0.5s
# [CV] epsilon=0.25, C=1.0, gamma=0.1, kernel=sigmoid ..................
# [CV]  epsilon=0.25, C=1.0, gamma=0.1, kernel=sigmoid, score=-5.37, total=   0.5s
# [CV] epsilon=0.25, C=1.0, gamma=0.1, kernel=sigmoid ..................
# [CV]  epsilon=0.25, C=1.0, gamma=0.1, kernel=sigmoid, score=-5.47, total=   0.5s
# [CV] epsilon=0.25, C=1.0, gamma=0.15, kernel=sigmoid .................
# [CV]  epsilon=0.25, C=1.0, gamma=0.15, kernel=sigmoid, score=-5.63, total=   0.5s
# [CV] epsilon=0.25, C=1.0, gamma=0.15, kernel=sigmoid .................
# [CV]  epsilon=0.25, C=1.0, gamma=0.15, kernel=sigmoid, score=-5.37, total=   0.5s
# [CV] epsilon=0.25, C=1.0, gamma=0.15, kernel=sigmoid .................
# [CV]  epsilon=0.25, C=1.0, gamma=0.15, kernel=sigmoid, score=-5.47, total=   0.5s
# [Parallel(n_jobs=1)]: Done 180 out of 180 | elapsed:  2.1min finished
# SIGMOID:
# (-5.496666666666667, {'epsilon': 0.05, 'C': 0.25, 'gamma': 0.05, 'kernel': 'sigmoid'})
# (-5.496666666666667, {'epsilon': 0.05, 'C': 0.25, 'gamma': 0.1, 'kernel': 'sigmoid'})
# (-5.496666666666667, {'epsilon': 0.05, 'C': 0.25, 'gamma': 0.15000000000000002, 'kernel': 'sigmoid'})
# (-5.496666666666666, {'epsilon': 0.1, 'C': 0.25, 'gamma': 0.05, 'kernel': 'sigmoid'})
# (-5.496666666666666, {'epsilon': 0.1, 'C': 0.25, 'gamma': 0.1, 'kernel': 'sigmoid'})
# (-5.496666666666666, {'epsilon': 0.1, 'C': 0.25, 'gamma': 0.15000000000000002, 'kernel': 'sigmoid'})
# (-5.496666666666666, {'epsilon': 0.15000000000000002, 'C': 0.25, 'gamma': 0.05, 'kernel': 'sigmoid'})
# (-5.496666666666666, {'epsilon': 0.15000000000000002, 'C': 0.25, 'gamma': 0.1, 'kernel': 'sigmoid'})
# (-5.496666666666666, {'epsilon': 0.15000000000000002, 'C': 0.25, 'gamma': 0.15000000000000002, 'kernel': 'sigmoid'})
# (-5.496666666666667, {'epsilon': 0.2, 'C': 0.25, 'gamma': 0.05, 'kernel': 'sigmoid'})
# (-5.496666666666667, {'epsilon': 0.2, 'C': 0.25, 'gamma': 0.1, 'kernel': 'sigmoid'})
# (-5.496666666666667, {'epsilon': 0.2, 'C': 0.25, 'gamma': 0.15000000000000002, 'kernel': 'sigmoid'})
# (-5.490000000000001, {'epsilon': 0.25, 'C': 0.25, 'gamma': 0.05, 'kernel': 'sigmoid'})
# (-5.490000000000001, {'epsilon': 0.25, 'C': 0.25, 'gamma': 0.1, 'kernel': 'sigmoid'})
# (-5.490000000000001, {'epsilon': 0.25, 'C': 0.25, 'gamma': 0.15000000000000002, 'kernel': 'sigmoid'})
# (-5.496666666666667, {'epsilon': 0.05, 'C': 0.5, 'gamma': 0.05, 'kernel': 'sigmoid'})
# (-5.496666666666667, {'epsilon': 0.05, 'C': 0.5, 'gamma': 0.1, 'kernel': 'sigmoid'})
# (-5.496666666666667, {'epsilon': 0.05, 'C': 0.5, 'gamma': 0.15000000000000002, 'kernel': 'sigmoid'})
# (-5.496666666666666, {'epsilon': 0.1, 'C': 0.5, 'gamma': 0.05, 'kernel': 'sigmoid'})
# (-5.496666666666666, {'epsilon': 0.1, 'C': 0.5, 'gamma': 0.1, 'kernel': 'sigmoid'})
# (-5.496666666666666, {'epsilon': 0.1, 'C': 0.5, 'gamma': 0.15000000000000002, 'kernel': 'sigmoid'})
# (-5.496666666666666, {'epsilon': 0.15000000000000002, 'C': 0.5, 'gamma': 0.05, 'kernel': 'sigmoid'})
# (-5.496666666666666, {'epsilon': 0.15000000000000002, 'C': 0.5, 'gamma': 0.1, 'kernel': 'sigmoid'})
# (-5.496666666666666, {'epsilon': 0.15000000000000002, 'C': 0.5, 'gamma': 0.15000000000000002, 'kernel': 'sigmoid'})
# (-5.496666666666667, {'epsilon': 0.2, 'C': 0.5, 'gamma': 0.05, 'kernel': 'sigmoid'})
# (-5.496666666666667, {'epsilon': 0.2, 'C': 0.5, 'gamma': 0.1, 'kernel': 'sigmoid'})
# (-5.496666666666667, {'epsilon': 0.2, 'C': 0.5, 'gamma': 0.15000000000000002, 'kernel': 'sigmoid'})
# (-5.490000000000001, {'epsilon': 0.25, 'C': 0.5, 'gamma': 0.05, 'kernel': 'sigmoid'})
# (-5.490000000000001, {'epsilon': 0.25, 'C': 0.5, 'gamma': 0.1, 'kernel': 'sigmoid'})
# (-5.490000000000001, {'epsilon': 0.25, 'C': 0.5, 'gamma': 0.15000000000000002, 'kernel': 'sigmoid'})
# (-5.496666666666667, {'epsilon': 0.05, 'C': 0.75, 'gamma': 0.05, 'kernel': 'sigmoid'})
# (-5.496666666666667, {'epsilon': 0.05, 'C': 0.75, 'gamma': 0.1, 'kernel': 'sigmoid'})
# (-5.496666666666667, {'epsilon': 0.05, 'C': 0.75, 'gamma': 0.15000000000000002, 'kernel': 'sigmoid'})
# (-5.496666666666666, {'epsilon': 0.1, 'C': 0.75, 'gamma': 0.05, 'kernel': 'sigmoid'})
# (-5.496666666666666, {'epsilon': 0.1, 'C': 0.75, 'gamma': 0.1, 'kernel': 'sigmoid'})
# (-5.496666666666666, {'epsilon': 0.1, 'C': 0.75, 'gamma': 0.15000000000000002, 'kernel': 'sigmoid'})
# (-5.496666666666666, {'epsilon': 0.15000000000000002, 'C': 0.75, 'gamma': 0.05, 'kernel': 'sigmoid'})
# (-5.496666666666666, {'epsilon': 0.15000000000000002, 'C': 0.75, 'gamma': 0.1, 'kernel': 'sigmoid'})
# (-5.496666666666666, {'epsilon': 0.15000000000000002, 'C': 0.75, 'gamma': 0.15000000000000002, 'kernel': 'sigmoid'})
# (-5.496666666666667, {'epsilon': 0.2, 'C': 0.75, 'gamma': 0.05, 'kernel': 'sigmoid'})
# (-5.496666666666667, {'epsilon': 0.2, 'C': 0.75, 'gamma': 0.1, 'kernel': 'sigmoid'})
# (-5.496666666666667, {'epsilon': 0.2, 'C': 0.75, 'gamma': 0.15000000000000002, 'kernel': 'sigmoid'})
# (-5.490000000000001, {'epsilon': 0.25, 'C': 0.75, 'gamma': 0.05, 'kernel': 'sigmoid'})
# (-5.490000000000001, {'epsilon': 0.25, 'C': 0.75, 'gamma': 0.1, 'kernel': 'sigmoid'})
# (-5.490000000000001, {'epsilon': 0.25, 'C': 0.75, 'gamma': 0.15000000000000002, 'kernel': 'sigmoid'})
# (-5.496666666666667, {'epsilon': 0.05, 'C': 1.0, 'gamma': 0.05, 'kernel': 'sigmoid'})
# (-5.496666666666667, {'epsilon': 0.05, 'C': 1.0, 'gamma': 0.1, 'kernel': 'sigmoid'})
# (-5.496666666666667, {'epsilon': 0.05, 'C': 1.0, 'gamma': 0.15000000000000002, 'kernel': 'sigmoid'})
# (-5.496666666666666, {'epsilon': 0.1, 'C': 1.0, 'gamma': 0.05, 'kernel': 'sigmoid'})
# (-5.496666666666666, {'epsilon': 0.1, 'C': 1.0, 'gamma': 0.1, 'kernel': 'sigmoid'})
# (-5.496666666666666, {'epsilon': 0.1, 'C': 1.0, 'gamma': 0.15000000000000002, 'kernel': 'sigmoid'})
# (-5.496666666666666, {'epsilon': 0.15000000000000002, 'C': 1.0, 'gamma': 0.05, 'kernel': 'sigmoid'})
# (-5.496666666666666, {'epsilon': 0.15000000000000002, 'C': 1.0, 'gamma': 0.1, 'kernel': 'sigmoid'})
# (-5.496666666666666, {'epsilon': 0.15000000000000002, 'C': 1.0, 'gamma': 0.15000000000000002, 'kernel': 'sigmoid'})
# (-5.496666666666667, {'epsilon': 0.2, 'C': 1.0, 'gamma': 0.05, 'kernel': 'sigmoid'})
# (-5.496666666666667, {'epsilon': 0.2, 'C': 1.0, 'gamma': 0.1, 'kernel': 'sigmoid'})
# (-5.496666666666667, {'epsilon': 0.2, 'C': 1.0, 'gamma': 0.15000000000000002, 'kernel': 'sigmoid'})
# (-5.490000000000001, {'epsilon': 0.25, 'C': 1.0, 'gamma': 0.05, 'kernel': 'sigmoid'})
# (-5.490000000000001, {'epsilon': 0.25, 'C': 1.0, 'gamma': 0.1, 'kernel': 'sigmoid'})
# (-5.490000000000001, {'epsilon': 0.25, 'C': 1.0, 'gamma': 0.15000000000000002, 'kernel': 'sigmoid'})
# Best: {'epsilon': 0.25, 'C': 0.25, 'gamma': 0.05, 'kernel': 'sigmoid'}
# RUN BEST PARAMETERS ON TEST DATA (2017):
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-019b572d72bf> in <module>()
#     190 # hyperparameter selection
#     191 if HYPERPARAMETER_SELECTION:
# --> 192     hyperparameter(train_x, train_y)
#
# <ipython-input-5-019b572d72bf> in hyperparameter(x, y)
#      98     print("RUN BEST PARAMETERS ON TEST DATA (2017):")
#      99     svr = sklearn.svm.SVR()
# --> 100     clf = sklearn.model_selection.GridSearchCV(svr, (param for param in overall_best_params), verbose=5, scoring=score)
#     101     clf.fit(test_x, test_y)
#     102     cvres = clf.cv_results_
#
# /usr/local/lib/python2.7/dist-packages/sklearn/model_selection/_search.pyc in __init__(self, estimator, param_grid, scoring, fit_params, n_jobs, iid, refit, cv, verbose, pre_dispatch, error_score, return_train_score)
#    1075             return_train_score=return_train_score)
#    1076         self.param_grid = param_grid
# -> 1077         _check_param_grid(param_grid)
#    1078
#    1079     def _get_param_iterator(self):
#
# /usr/local/lib/python2.7/dist-packages/sklearn/model_selection/_search.pyc in _check_param_grid(param_grid)
#     354                 raise ValueError("Parameter values for parameter ({0}) need "
#     355                                  "to be a sequence(but not a string) or"
# --> 356                                  " np.ndarray.".format(name))
#     357
#     358             if len(v) == 0:
#
# ValueError: Parameter values for parameter (epsilon) need to be a sequence(but not a string) or np.ndarray.
